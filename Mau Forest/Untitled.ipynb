# %%
import tweepy

#defining the keys
# consumer_key = 'V8cYGhi73zK4ncLqGH91BKMfX'
# consumer_secret = 'mEeMQfguWCmy8j32yJLu4bzNL38UgMq4f1B9atg7qtPQwzPFV7'
# access_key = '924336306481754113-ybsCoMFIIK84VjGFCRX9KhqUYA7aV3E'
# access_secret = 'oNU93zmzkgKqhbUeDPxwyisi1cqTuP4LVGQfnmTT9OhG1'

auth = tweepy.OAuthHandler('V8cYGhi73zK4ncLqGH91BKMfX' , 'mEeMQfguWCmy8j32yJLu4bzNL38UgMq4f1B9atg7qtPQwzPFV7')
auth.set_access_token('924336306481754113-ybsCoMFIIK84VjGFCRX9KhqUYA7aV3E', 'oNU93zmzkgKqhbUeDPxwyisi1cqTuP4LVGQfnmTT9OhG1')

api = tweepy.API(auth)

search_words = ['Mau Forest', '#MauForest', '#mauforest']

# %%
api.trends_closest(-1.2921, 36.8219)
# Out:
# [{'name': 'Nairobi',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/1528488',
#   'parentid': 23424863,
#   'country': 'Kenya',
#   'woeid': 1528488,
#   'countryCode': 'KE'}]

# %%
api.home_timeline()
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001BA3FE44DD8>, _json={'created_at': 'Tue Oct 01 09:39:19 +0000 2019', 'id': 1178967620797771784, 'id_str': '1178967620797771784', 'text': 'RT @AfromMedia: #ExposeAgeism https://t.co/Axoo3qUU0L', 'truncated': False, 'entities': {'hashtags': [{'text': 'ExposeAgeism', 'indices': [16, 29]}], 'symbols': [], 'user_mentions': [{'screen_name': 'AfromMedia', 'name': 'Afrom Media', 'id': 539815933, 'id_str': '539815933', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/Axoo3qUU0L', 'expanded_url': 'https://twitter.com/PerpetuaMachua/status/1178962313283588097', 'display_url': 'twitter.com/PerpetuaMachua…', 'indices': [30, 53]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 737709584572420097, 'id_str': '7377095845724200
# ...
