# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.
#
# Use the previously used notebook to find solutions for these. You are also free to google for pandas documentation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remember it is a scatter chart**

# %%
df3.plot.scatter('a', 'b', marker='o', color='red', figsize=(10,19))
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# df3.plot

# %%
df3.plot(kind='scatter', x='a', y='b', marker='o', color='red', figsize=(15,15))

# %%
# Solution here
df3.plot.line(x='a', y='b', marker='o', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Solution here
(df3['a'].value_counts(normalize=True)).plot.bar(x='a', y='percentage', figsize=(10,5))

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
acolumn = df3['a']
acolumn
# Out:
# 0      0.336272
# 1      0.980265
# 2      0.480387
# 3      0.502106
# 4      0.856602
# 5      0.705973
# 6      0.166724
# 7      0.054041
# 8      0.757839
# 9      0.425383
# 10     0.176837
# 11     0.221546
# 12     0.001350
# 13     0.537323
# 14     0.032284
# 15     0.488804
# 16     0.821116
# 17     0.202699
# 18     0.185218
# 19     0.842810
# 20     0.844033
# 21     0.163878
# 22     0.331902
# 23     0.501642
# 24     0.371520
# 25     0.994329
# 26     0.006800
# 27     0.203857
# 28     0.605779
# 29     0.477304
#          ...
# 470    0.020962
# 471    0.277962
# 472    0.718944
# 473    0.826840
# 474    0.230392
# 475    0.298387
# 476    0.832687
# 477    0.222610
# 478    0.957149
# 479    0.282431
# 480    0.070512
# 481    0.604156
# 482    0.675940
# 483    0.584853
# 484    0.354001
# 485    0.252384
# 486    0.495494
# 487    0.919797
# 488    0.298933
# 489    0.777968
# 490    0.690483
# 491    0.523531
# 492    0.113414
# 493    0.688181
# ...

# %%
acolumn.plot(kind="hist", color='maroon')

# %%
acolumn.plot(kind="hist", color='maroon', figsize=(10,10))

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
acolumn.plot(kind="hist", color='maroon', figsize=(10,10), alpha=0.5, bins=50,  normed='True', edgecolor='black')
# Out:
# C:\Users\InnCreator\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.** Today's Day 1 Lecture will come in habdy here

# %%
df3[['a', 'b']].plot.box()

# %%
df3[['a', 'b']].plot(kind='box')

# %%
corr = df.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-45893e33df67> in <module>
# ----> 1 corr = df.corr()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Great Job!
